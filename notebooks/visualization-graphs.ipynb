# %%
import pandas
import matplotlib.pyplot as plt

# %%
M_net_16_0001_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/M_net_16_Classes_0.0001.csv')
M_net_16_001_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/M_net_16_Classes_0.001.csv')
M_net_16_01_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/M_net_16_Classes_0.01.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(M_net_16_0001_Classes_df.Epoch, M_net_16_0001_Classes_df.train_accuracy, 'g', label="Training Accuracy for LR:0.0001")
ax1.plot(M_net_16_001_Classes_df.Epoch, M_net_16_001_Classes_df.train_accuracy, 'orange', label='Training Accuracy for LR:0.001')
ax1.plot(M_net_16_01_Classes_df.Epoch, M_net_16_01_Classes_df.train_accuracy, color='y', label="Training Accuracy for LR:0.01")
ax1.plot(M_net_16_0001_Classes_df.Epoch, M_net_16_0001_Classes_df.val_accuracy, 'g',linestyle='dashed', label="Validation Accuracy for LR:0.0001")
ax1.plot(M_net_16_001_Classes_df.Epoch, M_net_16_001_Classes_df.val_accuracy, 'orange',linestyle='dashed', label='Validation Accuracy for LR:0.001')
ax1.plot(M_net_16_01_Classes_df.Epoch, M_net_16_01_Classes_df.val_accuracy, color='y',linestyle='dashed', label="Validation Accuracy for LR:0.01")

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(M_net_16_0001_Classes_df.Epoch, M_net_16_0001_Classes_df.train_loss, 'g', label="Training loss for LR:0.0001")
ax2.plot(M_net_16_001_Classes_df.Epoch, M_net_16_001_Classes_df.train_loss, 'orange', label='Training loss for LR:0.001')
ax2.plot(M_net_16_01_Classes_df.Epoch, M_net_16_01_Classes_df.train_loss, color='y', label="Training loss for LR:0.01")
ax2.plot(M_net_16_0001_Classes_df.Epoch, M_net_16_0001_Classes_df.val_loss, 'g',linestyle='dashed', label="Validation loss for LR:0.0001")
ax2.plot(M_net_16_001_Classes_df.Epoch, M_net_16_001_Classes_df.val_loss, 'orange',linestyle='dashed', label='Validation loss for LR:0.001')
ax2.plot(M_net_16_01_Classes_df.Epoch, M_net_16_01_Classes_df.val_loss, color='y',linestyle='dashed', label="Validation loss for LR:0.01")

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset 3 (16 Classes)- Mobilenet")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#3_Mobilenet.jpg")

# %%
M_net_5_0001_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/M_net_5_Classes_0.0001.csv')
M_net_5_001_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/M_net_5_Classes_0.001.csv')
M_net_5_01_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/M_net_5_Classes_0.01.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(M_net_5_0001_Classes_df.Epoch, M_net_5_0001_Classes_df.train_accuracy, 'g', label="Training Accuracy for LR:0.0001")
ax1.plot(M_net_5_001_Classes_df.Epoch, M_net_5_001_Classes_df.train_accuracy, 'orange', label='Training Accuracy for LR:0.001')
ax1.plot(M_net_5_01_Classes_df.Epoch, M_net_5_01_Classes_df.train_accuracy, color='y', label="Training Accuracy for LR:0.01")
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(M_net_5_0001_Classes_df.Epoch, M_net_5_0001_Classes_df.train_loss, 'g', label="Training loss for LR:0.0001")
ax2.plot(M_net_5_001_Classes_df.Epoch, M_net_5_001_Classes_df.train_loss, 'orange', label='Training loss for LR:0.001')
ax2.plot(M_net_5_01_Classes_df.Epoch, M_net_5_01_Classes_df.train_loss, color='y', label="Training loss for LR:0.01")
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset 1 (5 Classes)- Mobilenet")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#1_Mobilenet.jpg")

# %%
r_net_5_0001_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/r_net_5_Classes_0.0001.csv')
r_net_5_001_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/r_net_5_Classes_0.001.csv')
r_net_5_01_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/r_net_5_Classes_0.01.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(r_net_5_0001_Classes_df.Epoch, r_net_5_0001_Classes_df.train_accuracy, 'g', label="Training Accuracy for LR:0.0001")
ax1.plot(r_net_5_001_Classes_df.Epoch, r_net_5_001_Classes_df.train_accuracy, 'orange', label='Training Accuracy for LR:0.001')
ax1.plot(r_net_5_01_Classes_df.Epoch, r_net_5_01_Classes_df.train_accuracy, color='y', label="Training Accuracy for LR:0.01")

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(r_net_5_0001_Classes_df.Epoch, r_net_5_0001_Classes_df.train_loss, 'g', label="Training loss for LR:0.0001")
ax2.plot(r_net_5_001_Classes_df.Epoch, r_net_5_001_Classes_df.train_loss, 'orange', label='Training loss for LR:0.001')
ax2.plot(r_net_5_01_Classes_df.Epoch, r_net_5_01_Classes_df.train_loss, color='y', label="Training loss for LR:0.01")

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset 1 (5 Classes)- Resnet")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#1_Resnet_LearningRate.jpg")

# %%
vgg_5_0001_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/vgg_5_Classes_0.0001L.csv')
vgg_5_001_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/vgg_5_Classes_0.001L.csv')
vgg_5_01_Classes_df = pandas.read_csv('/kaggle/input/csvfileslearningrate/vgg_5_Classes_0.01L.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(vgg_5_0001_Classes_df.Epoch,vgg_5_0001_Classes_df.train_accuracy, 'g', label="Training Accuracy for LR:0.0001")
ax1.plot(vgg_5_001_Classes_df.Epoch, vgg_5_001_Classes_df.train_accuracy, 'orange', label='Training Accuracy for LR:0.001')
ax1.plot(vgg_5_01_Classes_df.Epoch,vgg_5_01_Classes_df.train_accuracy, color='y', label="Training Accuracy for LR:0.01")
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(vgg_5_0001_Classes_df.Epoch, vgg_5_0001_Classes_df.train_loss, 'g', label="Training loss for LR:0.0001")
ax2.plot(vgg_5_001_Classes_df.Epoch, vgg_5_001_Classes_df.train_loss, 'orange', label='Training loss for LR:0.001')
ax2.plot(vgg_5_01_Classes_df.Epoch, vgg_5_01_Classes_df.train_loss, color='y', label="Training loss for LR:0.01")
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset 1 (5 Classes)- VGG")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#1_VGG.jpg")

# %% [markdown]
# **BATCH Graphs**

# %%
import pandas
import matplotlib.pyplot as plt

# %%
M_net_16_128_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/M_net_16_Classes_128.csv')
M_net_16_64_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/M_net_16_Classes_64.csv')
M_net_16_32_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/M_net_16_Classes_32.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(M_net_16_128_Classes_df.Epoch, M_net_16_128_Classes_df.train_accuracy, 'g', label="Training Accuracy for batch Size:128")
ax1.plot(M_net_16_64_Classes_df.Epoch, M_net_16_64_Classes_df.train_accuracy, 'orange', label='Training Accuracy for batch Size:64')
ax1.plot(M_net_16_32_Classes_df.Epoch, M_net_16_32_Classes_df.train_accuracy, color='y', label="Training Accuracy for batch Size:32")
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(M_net_16_128_Classes_df.Epoch, M_net_16_128_Classes_df.train_loss, 'g', label="Training loss for batch Size:128")
ax2.plot(M_net_16_64_Classes_df.Epoch, M_net_16_64_Classes_df.train_loss, 'orange', label='Training loss for batch Size:64')
ax2.plot(M_net_16_32_Classes_df.Epoch, M_net_16_32_Classes_df.train_loss, color='y', label="Training loss for batch Size:32")
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset 3 (16 Classes)- Mobilenet")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#3_Mobilenet_batchgraph.jpg")

# %%
M_net_5_128_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/M_net_5_Classes_128.csv')
M_net_5_64_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/M_net_5_Classes_64.csv')
M_net_5_32_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/M_net_5_Classes_32.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(M_net_5_128_Classes_df.Epoch, M_net_5_128_Classes_df.train_accuracy, 'g', label="Training Accuracy for batch Size:128")
ax1.plot(M_net_5_64_Classes_df.Epoch, M_net_5_64_Classes_df.train_accuracy, 'orange', label='Training Accuracy for batch Size:64')
ax1.plot(M_net_5_32_Classes_df.Epoch, M_net_5_32_Classes_df.train_accuracy, color='y', label="Training Accuracy for batch Size:32")
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(M_net_5_128_Classes_df.Epoch, M_net_5_128_Classes_df.train_loss, 'g', label="Training loss for batch Size:128")
ax2.plot(M_net_5_64_Classes_df.Epoch, M_net_5_64_Classes_df.train_loss, 'orange', label='Training loss for batch Size:64')
ax2.plot(M_net_5_32_Classes_df.Epoch, M_net_5_32_Classes_df.train_loss, color='y', label="Training loss for batch Size:32")
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset 1 (5 Classes)- Mobilenet")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#1_Mobilenet_batchgraph.jpg")

# %%
r_net_5_128_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/r_net_5_Classes_128.csv')
r_net_5_64_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/r_net_5_Classes_64.csv')
r_net_5_32_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/r_net_5_Classes_32.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(r_net_5_128_Classes_df.Epoch, r_net_5_128_Classes_df.train_accuracy, 'g', label="Training Accuracy for batch Size:128")
ax1.plot(r_net_5_64_Classes_df.Epoch, r_net_5_64_Classes_df.train_accuracy, 'orange', label='Training Accuracy for batch Size:64')
ax1.plot(r_net_5_32_Classes_df.Epoch, r_net_5_32_Classes_df.train_accuracy, color='y', label="Training Accuracy for batch Size:32")
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(r_net_5_128_Classes_df.Epoch, r_net_5_128_Classes_df.train_loss, 'g', label="Training loss for batch Size:128")
ax2.plot(r_net_5_64_Classes_df.Epoch, r_net_5_64_Classes_df.train_loss, 'orange', label='Training loss for batch Size:64')
ax2.plot(r_net_5_32_Classes_df.Epoch, r_net_5_32_Classes_df.train_loss, color='y', label="Training loss for batch Size:32")
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset 1 (5 Classes)- resnet")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#1_resnet_batchgraph.jpg")

# %%
vgg_5_128_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/vgg_5_Classes_128.csv')
vgg_5_64_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/vgg_5_Classes_64.csv')
vgg_5_32_Classes_df = pandas.read_csv('/kaggle/input/csvfilesbatchsize/vgg_5_Classes_32.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(vgg_5_128_Classes_df.Epoch, vgg_5_128_Classes_df.train_accuracy, 'g', label="Training Accuracy for batch Size:128")
ax1.plot(vgg_5_64_Classes_df.Epoch, vgg_5_64_Classes_df.train_accuracy, 'orange', label='Training Accuracy for batch Size:64')
ax1.plot(vgg_5_32_Classes_df.Epoch, vgg_5_32_Classes_df.train_accuracy, color='y', label="Training Accuracy for batch Size:32")
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(vgg_5_128_Classes_df.Epoch, vgg_5_128_Classes_df.train_loss, 'g', label="Training loss for batch Size:128")
ax2.plot(vgg_5_64_Classes_df.Epoch, vgg_5_64_Classes_df.train_loss, 'orange', label='Training loss for batch Size:64')
ax2.plot(vgg_5_32_Classes_df.Epoch, vgg_5_32_Classes_df.train_loss, color='y', label="Training loss for batch Size:32")
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset 1 (5 Classes)- VGG")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#VGG.jpg")

# %% [markdown]
# **Model Comparision**

# %%
import pandas
import matplotlib.pyplot as plt

# %%
M_net_5_Classes_df = pandas.read_csv('/kaggle/input/csvfilesmodelcomparision/M_net_5_Classes.csv')
r_net_5_Classes_df = pandas.read_csv('/kaggle/input/csvfilesmodelcomparision/r_net_5_Classes.csv')
vgg_5_Classes_df = pandas.read_csv('/kaggle/input/csvfilesmodelcomparision/vgg_5_Classes.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(M_net_5_Classes_df.Epoch, M_net_5_Classes_df.train_accuracy, 'g', label="Training Accuracy: Mobilenet")
ax1.plot(r_net_5_Classes_df.Epoch, r_net_5_Classes_df.train_accuracy, 'orange', label='Training Accuracy: resnet')
ax1.plot(vgg_5_Classes_df.Epoch, vgg_5_Classes_df.train_accuracy, color='y', label="Training Accuracy: VGG")
ax1.plot(M_net_5_Classes_df.Epoch, M_net_5_Classes_df.val_accuracy, 'g', linestyle='dashed',label="Validation Accuracy: Mobilenet")
ax1.plot(r_net_5_Classes_df.Epoch, r_net_5_Classes_df.val_accuracy, 'orange',linestyle='dashed', label='Validation Accuracy: resnet')
ax1.plot(vgg_5_Classes_df.Epoch, vgg_5_Classes_df.val_accuracy, color='y',linestyle='dashed', label="Validation Accuracy: VGG")

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(M_net_5_Classes_df.Epoch, M_net_5_Classes_df.train_loss, 'g', label="Training loss: Mobilenet")
ax2.plot(r_net_5_Classes_df.Epoch, r_net_5_Classes_df.train_loss, 'orange', label='Training loss: resnet')
ax2.plot(vgg_5_Classes_df.Epoch, vgg_5_Classes_df.train_loss, color='y', label="Training loss: VGG")
ax2.plot(M_net_5_Classes_df.Epoch, M_net_5_Classes_df.val_loss, 'g',linestyle='dashed', label="Validation loss: Mobilenet")
ax2.plot(r_net_5_Classes_df.Epoch, r_net_5_Classes_df.val_loss, 'orange',linestyle='dashed', label='Validation loss: resnet')
ax2.plot(vgg_5_Classes_df.Epoch, vgg_5_Classes_df.val_loss, color='y',linestyle='dashed', label="Validation loss: VGG")
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Model Comparision - Dataset 1 (5 Classes )")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#1_Model Comparision.jpg")

# %% [markdown]
# **Dataset Comparision**

# %%
import pandas
import matplotlib.pyplot as plt

# %%
r_net_16_Classes_df = pandas.read_csv('/kaggle/input/csvfilesdatasetcomparision/r_net_16_Classes.csv')
r_net_7_Classes_df = pandas.read_csv('/kaggle/input/csvfilesdatasetcomparision/resnet_7_Classes.csv')
r_net_5_Classes_df = pandas.read_csv('/kaggle/input/csvfilesdatasetcomparision/r_net_5_Classes.csv')

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(r_net_16_Classes_df.Epoch, r_net_16_Classes_df.train_accuracy, 'g', label="Training Accuracy: Dataset3")
ax1.plot(r_net_7_Classes_df.Epoch, r_net_7_Classes_df.train_accuracy, 'orange', label='Training Accuracy: Dataset2')
ax1.plot(r_net_5_Classes_df.Epoch, r_net_5_Classes_df.train_accuracy, color='y', label="Training Accuracy: Dataset1")
ax1.plot(r_net_16_Classes_df.Epoch, r_net_16_Classes_df.val_accuracy, 'g', linestyle='dashed',label="Validation Accuracy: Dataset3")
ax1.plot(r_net_7_Classes_df.Epoch, r_net_7_Classes_df.val_accuracy, 'orange', linestyle='dashed',label='Validation Accuracy: Dataset2')
ax1.plot(r_net_5_Classes_df.Epoch, r_net_5_Classes_df.val_accuracy, color='y',linestyle='dashed', label="Validation Accuracy: Dataset1")
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(r_net_16_Classes_df.Epoch, r_net_16_Classes_df.train_loss, 'g', label="Training loss: Dataset3")
ax2.plot(r_net_7_Classes_df.Epoch, r_net_7_Classes_df.train_loss, 'orange', label='Training loss: Dataset2')
ax2.plot(r_net_5_Classes_df.Epoch, r_net_5_Classes_df.train_loss, color='y', label="Training loss: Dataset1")
ax2.plot(r_net_16_Classes_df.Epoch, r_net_16_Classes_df.val_loss, 'g',linestyle='dashed', label="Validation loss: Dataset3")
ax2.plot(r_net_7_Classes_df.Epoch, r_net_7_Classes_df.val_loss, 'orange',linestyle='dashed', label='Validation loss: Dataset2')
ax2.plot(r_net_5_Classes_df.Epoch, r_net_5_Classes_df.val_loss, color='y',linestyle='dashed', label="Validation loss: Dataset1")
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset Comparision - Resnet")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_Comparision_for_Resnet")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(r_net_5_0001_Classes_df.Epoch, r_net_5_0001_Classes_df.train_accuracy, 'g', label="Training Accuracy for LR:0.0001")
ax1.plot(r_net_5_001_Classes_df.Epoch, r_net_5_001_Classes_df.train_accuracy, 'orange', label='Training Accuracy for LR:0.001')
ax1.plot(r_net_5_01_Classes_df.Epoch, r_net_5_01_Classes_df.train_accuracy, color='y', label="Training Accuracy for LR:0.01")
ax1.plot(r_net_5_0001_Classes_df.Epoch, r_net_5_0001_Classes_df.val_accuracy, 'g', linestyle='dashed',label="validation Accuracy for LR:0.0001")
ax1.plot(r_net_5_001_Classes_df.Epoch, r_net_5_001_Classes_df.val_accuracy, 'orange',linestyle='dashed', label='validation Accuracy for LR:0.001')
ax1.plot(r_net_5_01_Classes_df.Epoch, r_net_5_01_Classes_df.val_accuracy, color='y',linestyle='dashed', label="validation Accuracy for LR:0.01")

ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(r_net_5_0001_Classes_df.Epoch, r_net_5_0001_Classes_df.train_loss, 'g', label="Training loss for LR:0.0001")
ax2.plot(r_net_5_001_Classes_df.Epoch, r_net_5_001_Classes_df.train_loss, 'orange', label='Training loss for LR:0.001')
ax2.plot(r_net_5_01_Classes_df.Epoch, r_net_5_01_Classes_df.train_loss, color='y', label="Training loss for LR:0.01")
ax2.plot(r_net_5_0001_Classes_df.Epoch, r_net_5_0001_Classes_df.val_loss, 'g',linestyle='dashed', label="validation loss for LR:0.0001")
ax2.plot(r_net_5_001_Classes_df.Epoch, r_net_5_001_Classes_df.val_loss, 'orange', linestyle='dashed',label='validation loss for LR:0.001')
ax2.plot(r_net_5_01_Classes_df.Epoch, r_net_5_01_Classes_df.val_loss, color='y',linestyle='dashed', label="validation loss for LR:0.01")

ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset 1 (5 Classes)- Resnet")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#1_Resnet.jpg")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))

# plot for accuracy
ax1.plot(r_net_5_128_Classes_df.Epoch, r_net_5_128_Classes_df.train_accuracy, 'g', label="Training Accuracy for batch Size:128")
ax1.plot(r_net_5_64_Classes_df.Epoch, r_net_5_64_Classes_df.train_accuracy, 'orange', label='Training Accuracy for batch Size:64')
ax1.plot(r_net_5_32_Classes_df.Epoch, r_net_5_32_Classes_df.train_accuracy, color='y', label="Training Accuracy for batch Size:32")
ax1.plot(r_net_5_128_Classes_df.Epoch, r_net_5_128_Classes_df.val_accuracy, 'g',linestyle='dashed', label="Validation Accuracy for batch Size:128")
ax1.plot(r_net_5_64_Classes_df.Epoch, r_net_5_64_Classes_df.val_accuracy, 'orange',linestyle='dashed', label='Validation Accuracy for batch Size:64')
ax1.plot(r_net_5_32_Classes_df.Epoch, r_net_5_32_Classes_df.val_accuracy, color='y',linestyle='dashed', label="Validation Accuracy for batch Size:32")
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# plot for loss
# plot for accuracy
ax2.plot(r_net_5_128_Classes_df.Epoch, r_net_5_128_Classes_df.train_loss, 'g', label="Training loss for batch Size:128")
ax2.plot(r_net_5_64_Classes_df.Epoch, r_net_5_64_Classes_df.train_loss, 'orange', label='Training loss for batch Size:64')
ax2.plot(r_net_5_32_Classes_df.Epoch, r_net_5_32_Classes_df.train_loss, color='y', label="Training loss for batch Size:32")
ax2.plot(r_net_5_128_Classes_df.Epoch, r_net_5_128_Classes_df.val_loss, 'g',linestyle='dashed', label="Validation loss for batch Size:128")
ax2.plot(r_net_5_64_Classes_df.Epoch, r_net_5_64_Classes_df.val_loss, 'orange',linestyle='dashed', label='Validation loss for batch Size:64')
ax2.plot(r_net_5_32_Classes_df.Epoch, r_net_5_32_Classes_df.val_loss, color='y',linestyle='dashed', label="Validation loss for batch Size:32")
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.suptitle("Dataset 1 (5 Classes)- resnet")
plt.tight_layout()
plt.show()

fig.savefig("Dataset_#1_resnet_batchgraph.jpg")
